# %% [markdown]
# <a href="https://colab.research.google.com/github/im1xd/WebScraping/blob/playersB/players_bundesliga_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **استيراد المكتبات**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **استيراد الموقع واستخراد البيانات**

# %%
webpage = requests.get("https://www.bundesliga.com/en/bundesliga/player")
soup = BeautifulSoup(webpage.content, "html.parser")
"https://www.bundesliga.com/en/bundesliga/player"
# Out:
# 'https://www.bundesliga.com/en/bundesliga/player'

# %% [markdown]
# # **تحديد الكلاس الذي تريد استيراده**

# %%
names_column=soup.find_all(attrs={"class":"names"})
names_list=[]

playerNumber_column=soup.find_all(attrs={"class":"playerNumber"})
playerNumber_list=[]

# %% [markdown]
# # ***مرحلة المعالجة (Processing / Data Processing)***

# %%
for x in names_column[1:]:
    names_list.append(x.get_text())

for x in playerNumber_column[1:]:
    playerNumber_list.append(x.get_text())

# %% [markdown]
# ***طباعة النتائج***

# %%
print(names_list)
print(playerNumber_list)
# Out:
# ['SvenUlreich', 'JannisBärtl', 'JonasUrbig', 'LeonKlanac', 'DayotUpamecano', 'MinjaeKim', 'JonathanTah', 'AlphonsoDavies', 'HirokiIto', 'RaphaëlGuerreiro', 'SachaBoey', 'CassianoKiala', 'JosipStanišić', 'JoshuaKimmich', 'LeonGoretzka', 'JamalMusiala', 'MichaelOlise', 'TomBischof', 'KonradLaimer', 'LennartKarl', 'AleksandarPavlović', 'DavidSantos Daiber', 'SergeGnabry', 'HarryKane', 'NicolasJackson', 'LuisDíaz', 'WisdomMike', 'MarkFlekken', 'JanisBlaswich', 'NiklasLomb', 'JarellQuansah', 'LoïcBadé', 'EdmondTapsoba', 'Arthur', 'AxelTape', 'AlejandroGrimaldo', 'LucasVázquez', 'JeanuëlBelocian', 'EzequielFernández', 'JonasHofmann', 'RobertAndrich', 'ClaudioEcheverri', 'MalikTillman', 'AleixGarcía', 'ExequielPalacios', 'JeremiahMensah', 'IbrahimMaza', 'MartinTerrier', 'PatrikSchick', 'EliesseBen Seghir', 'AlejoSarco', 'ErnestPoku', 'NathanTella', 'ChristianKofane', 'KenIzekor', 'KamilGrabara', 'PavaoPervan', 'MariusMüller', 'JakubZielinski', 'KilianFischer', 'DenisVavro', 'KonstantinosKou
# ...

# %% [markdown]
# # ***وضعها في ملف csv***

# %%
df = pd.DataFrame({
    "names"  : names_list
  , "playerNumber" : playerNumber_list
})
df.to_csv("players_list.csv", index=False, encoding="utf-8")

print("players_list.csv ")
# Out:
# players_list.csv
